# %%
from sqlalchemy import create_engine
import pandas as pd
import os

# %%
engine = create_engine('mysql+pymysql://dva:DVA2019!@dvaproject.c9f0lti9xqdg.us-east-1.rds.amazonaws.com/reviews?charset=utf8', echo=False)

# %%
book_genres = pd.read_sql("book_genre_data", con=engine) 

movie_genres = pd.read_sql("imdb_genre_map", con=engine)

# %%
book_genres.head()
# Out:
#    book_id           genre
# 0   915001         Fiction
# 1   915001  Womens Fiction
# 2   915001       Chick Lit
# 3   915001           Drama
# 4   915001         Romance

# %%
book_genres['genre'].value_counts()
# Out:
# Fiction                      1366
# Classics                      590
# Historical                    374
# Historical Fiction            361
# Mystery                       350
# Thriller                      304
# Literature                    287
# Crime                         223
# Novels                        212
# Fantasy                       207
# Cultural                      194
# Adventure                     185
# Romance                       149
# Science Fiction               148
# Young Adult                   141
# European Literature           127
# Horror                        122
# Childrens                     106
# Westerns                       96
# War                            90
# Contemporary                   88
# Humor                          79
# American                       71
# Noir                           69
# Suspense                       65
# France                         62
# Espionage                      51
# ...

# %%
movies_genres  = movie_genres[movie_genres['genre'] != "\N"]

movie_genres['genre'].value_counts()
# Out:
#   File "<ipython-input-15-7968c38841bc>", line 1
#     movies_genres  = movie_genres[movie_genres['genre'] != "\N"]
#                                                           ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 0-1: malformed \N character escape

# %%
hp_ids = [2, 6, 15881, 1, 5, 3, 136251]

books = pd.read_sql("book_data", con=engine)

# %%
books.sort_values(by="book_id")
# Out:
#        book_id  avg_rating  rating_count  review_count  \
# 906          3        4.46       5799402         93027
# 20          33        4.49        491925         10508
# 640         34        4.35       2068325         18185
# 960         93        3.98        162321          3186
# 869        218        3.94           559            54
# 266        228        4.11          1117            69
# 122        304        3.83         21318           835
# 1132       656        4.10        231531          9562
# 674        685        3.63          9200           717
# 1014       890        3.86       1701929         29098
# 717       1078        3.98        207966          9098
# 103       1296        4.03        205455          5807
# 631       1381        3.75        782169          9990
# 247       1772        3.45           292            25
# 69        1852        3.85        284931          8357
# 79        1953        3.83        736717         15078
# ...

# %%
books = pd.read_sql("wiki_", con=engine)
